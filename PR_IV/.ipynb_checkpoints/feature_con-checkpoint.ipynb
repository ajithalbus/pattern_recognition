#          1.33      ,  1.41      ,  1.49      ,  1.50999849,  1.54999849,
#          1.54999849,  1.53      ,  1.49      ,  1.42999849,  1.37      ,
#          1.33      ,  1.30999849,  1.30999849,  1.33      ,  1.41      ,
#          1.57      ,  1.75000151,  1.85      ,  1.97      ,  2.03000151,
#          2.05      ,  2.01      ,  1.97      ,  1.91000151,  1.89      ,
#          1.91000151,  1.93      ,  1.99000151,  2.03000151,  2.23636364,
#          2.23636364,  2.23636364,  2.23636364,  2.23636364,  2.25908919,
#          2.28181818,  2.32727273,  2.34999828,  2.37272727,  2.39545283,
#          2.41818182,  2.44090737,  2.44090737,  2.44090737,  2.44090737,
#          2.41818182,  2.39545283,  2.34999828,  2.32727273,  2.28181818,
#          2.23636364,  2.21363465,  2.1681801 ,  2.14545455,  2.12272556,
#          2.1       ,  2.1       ,  2.1       ,  2.12272556,  2.1681801 ,
#          2.19090909,  2.23636364,  2.25908919,  2.30454374,  2.32727273,
#          2.32727273,  2.34999828,  2.34999828,  2.37272727,  2.39545283,
#          2.41818182,  2.44090737,  2.46363636,  2.48636192,  2.53181647,
#          2.55454545,  2.6       ,  2.62272899,  2.64545455,  2.66818353,
#          2.66818353,  2.66818353,  2.64545455,  2.64545455,  2.64545455,
#          2.64545455,  2.64545455,  2.66818353,  2.69090909,  2.73636364,
#          2.82727273,  2.87272727,  2.96363636,  3.00909091,  3.05454545,
#          3.07727444,  3.1       ,  3.1       ,  3.07727444,  3.05454545,
#          3.00909091,  2.96363636,  2.96363636,  2.94091081,  2.94091081,
#          2.96363636,  2.98636535]]), '__header__': 'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sun Oct 22 15:02:49 2017', '__globals__': []}

# %%
fle=open('./data_set/HandWritten_data/DATA/FeaturesHW/dA.ldf','r')
arr=[]
i=-1
for line in fle:
    #print line
    i+=1
    if i%3==0 or i%3==1:
        continue
    ln=np.fromstring(line,sep=' ')[1:]
    ln=np.reshape(ln,(ln.shape[0]/2,2))
    
    arr.append(ln)

# %%
def curvature(xd,yd,xdd,ydd):
    n=xd*ydd-yd*xdd
    d=(xd**2+yd**2)**1.5
    if d==0:
        if n>0:
            return float('inf')
        elif n<0:
            return float('-inf')
        else:
            return 0
    return n/d

# %%
j=0
for ass in arr:
    gradx=np.gradient(ass[:,0])
    grady=np.gradient(ass[:,1])
    dgradx=np.gradient(gradx)
    dgrady=np.gradient(grady)
    mn=np.c_[ass,gradx,grady,dgradx,dgrady]

    curv=[curvature(i[2],i[3],i[4],i[5]) for i in mn]

    final=np.c_[mn,curv]
    np.savetxt('./created/1_'+str(j)+'.txt',final)
    j+=1
